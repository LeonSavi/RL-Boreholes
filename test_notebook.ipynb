# %%
import pandas as pd

df_ocr = pd.read_parquet("data//ocr_output//3357.parquet")

df_ocr.head()
# Out:
#   dataset borehole  depth_top  depth_base   depth  \
# 0     OCR     3357     3341.0      3737.0  3539.0
# 1     OCR     3357     3340.0      3737.0  3538.5
# 2     OCR     3357      151.0       314.0   232.5
# 3     OCR     3357      314.0       598.0   456.0
# 4     OCR     3357     1412.0      1471.0  1441.5
#
#                                          description formation  x_rd  y_rd  \
# 0  Trip Gas at 3739 m: cut, bright yetlow fluores...      None   NaN   NaN
# 1  iCa 0.57% avaluated to come from Zechstein C8L...      None   NaN   NaN
# 2  Fine to coarse grained SAND of clear, colorles...      None   NaN   NaN
# 3  Medium dark grey, soft and sandy to silty CLAY...      None   NaN   NaN
# 4  Mm Medium dark grey, soft to firm, locally sti...      None   NaN   NaN
#
#    page_number
# 0           11
# 1           11
# 2           26
# 3           26
# 4           26

# %%
len(df_ocr)
# Out:
# 69
